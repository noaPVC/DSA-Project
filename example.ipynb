# %% [markdown]
# # This is some test markdown describing our endeavors..

# %%
print('python interpreter is working correctly!')
# Out:
# python interpreter is working correctly!

# %% [markdown]
# This is another piece of just documentation, maybe of the previous result?
